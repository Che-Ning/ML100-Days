# %% [markdown]
# # 作業1：請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# [Black Friday:A study of sales trough consumer behaviours](https://www.kaggle.com/mehdidag/black-friday)
#
# #### 1. 你選的這組資料為何重要
#     此數據集是零售商店的交易樣本，主要針對不同客戶所購買的產品，而零售商店希望了解客戶的購買行為。
# #### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     Analytics Vidhya主辦的競賽
# #### 3. 蒐集而來的資料型態為何
#     結構化資料，共包括537577條數據，12個欄位:
#     User_ID、Product_ID、Gender、Age、Occupation、City_Category、Stay_In_Current_City_Years、Marital_Status
#     、Product_Category_1、Product_Category_2、Product_Category_3、Purchase。
# #### 4. 這組資料想解決的問題如何評估
#     回歸問題: 預測因變量（購買量）
#     分類問題: 預測購買商品的客戶屬性特點、預測客戶購買的商品類別

# %% [markdown]
# # 作業2：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     核心問題為每月的營業淨收入，假設與所在區域、載客時間、單趟收入、人潮最多的時段和區域資訊..等數據有關。
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     載客平台(如：所在區域、載客時間、單趟收入、人潮最多的時段和區域資訊等數據)，並透過分析當天的時空情境（星期、時段和區域等）和外部因素（天氣、節慶、活動等）及計程車當下位置點，推薦司機優先去哪個區域的熱點載客，可有效降低空車率提升運將業績。
#
# #### 3. 蒐集而來的資料型態為何
#     結構化資料(所在區域、載客時間、單趟收入....等)
#
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     假設所在區域、載客時間、單趟收入、人潮最多的時段和區域資訊...等數據,以時間序列、回歸模型(MSE)方式驗證。

# %% [markdown]
# # 作業3：請點選檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
#
# 資料夾結構建立規則提醒：ML100 > data資料夾 & ipynb檔
#
# (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)
#
# ![D1](https://ai100-fileentity.cupoy.com/homework/D1/1544521017885/large)
#
# 提交作業請上傳Day_001_HW.ipynb檔案到您的github帳號之後，再提供連結，(作業1.2申論題目可一併寫在HW檔案裡)
# 提醒：同步Github本機資料夾時，不需將Data一起同步，只需要將作業檔同步即可。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    mse = np.mean((y-y_hat)**2)
    return mse

# %%
def mean_absolute_error(y, y_hat):
    mae = np.mean(abs(y-y_hat))
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 234.081
# The Mean absolute error is 12.037
